# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/vehicle_emission_dataset.csv')
df.head()
# Out:
#   Vehicle Type Fuel Type  Engine Size  Age of Vehicle  Mileage       Speed  \
# 0   Motorcycle  Electric     2.747609              22   291288   49.083255
# 1          Bus  Electric     5.743714               3   188398   23.460311
# 2          Bus    Hybrid     4.606368              17   281451  115.508350
# 3        Truck  Electric     3.913024               4   151321   18.540217
# 4        Truck    Hybrid     1.611297              15    91810  109.596566
#
#    Acceleration Road Type Traffic Conditions  Temperature   Humidity  \
# 0      1.887738   Highway           Moderate    13.880458  52.883905
# 1      3.544147      City              Heavy    19.136947   5.697343
# 2      4.646886   Highway          Free flow     8.123428   3.953116
# 3      3.581004     Rural              Heavy    35.994893   0.509678
# 4      3.879303   Highway           Moderate    14.793481  52.450884
#
#    Wind Speed  Air Pressure  CO2 Emissions  NOx Emissions  PM2.5 Emissions  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Vehicle Type        10000 non-null  object
#  1   Fuel Type           10000 non-null  object
#  2   Engine Size         10000 non-null  float64
#  3   Age of Vehicle      10000 non-null  int64
#  4   Mileage             10000 non-null  int64
#  5   Speed               10000 non-null  float64
#  6   Acceleration        10000 non-null  float64
#  7   Road Type           10000 non-null  object
#  8   Traffic Conditions  10000 non-null  object
#  9   Temperature         10000 non-null  float64
#  10  Humidity            10000 non-null  float64
#  11  Wind Speed          10000 non-null  float64
#  12  Air Pressure        10000 non-null  float64
#  13  CO2 Emissions       10000 non-null  float64
#  14  NOx Emissions       10000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Vehicle Type          0
# Fuel Type             0
# Engine Size           0
# Age of Vehicle        0
# Mileage               0
# Speed                 0
# Acceleration          0
# Road Type             0
# Traffic Conditions    0
# Temperature           0
# Humidity              0
# Wind Speed            0
# Air Pressure          0
# CO2 Emissions         0
# NOx Emissions         0
# PM2.5 Emissions       0
# VOC Emissions         0
# SO2 Emissions         0
# Emission Level        0
# dtype: int64

# %%
df.describe()
# Out:
#         Engine Size  Age of Vehicle        Mileage         Speed  \
# count  10000.000000    10000.000000   10000.000000  10000.000000
# mean       3.369630       14.490000  148995.708000     59.448818
# std        1.495677        8.584339   87068.385915     34.437175
# min        0.800061        0.000000      56.000000      0.000664
# 25%        2.080910        7.000000   73589.750000     29.502708
# 50%        3.361149       15.000000  148914.500000     59.701114
# 75%        4.648033       22.000000  224359.500000     88.499982
# max        5.998532       29.000000  299863.000000    119.974725
#
#        Acceleration   Temperature      Humidity    Wind Speed  Air Pressure  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       2.491924     14.935772     50.144758     10.027946   1000.199354
# std        1.446130     14.432900     28.787763      5.735533     28.789590
# ...

# %%
df.drop(columns=["Engine Size","Mileage","Speed","Acceleration","Wind Speed"],inplace=True)
df.head()
# Out:
#   Vehicle Type Fuel Type  Age of Vehicle Road Type Traffic Conditions  \
# 0   Motorcycle  Electric              22   Highway           Moderate
# 1          Bus  Electric               3      City              Heavy
# 2          Bus    Hybrid              17   Highway          Free flow
# 3        Truck  Electric               4     Rural              Heavy
# 4        Truck    Hybrid              15   Highway           Moderate
#
#    Temperature   Humidity  Air Pressure  CO2 Emissions  NOx Emissions  \
# 0    13.880458  52.883905    955.411642     179.930088       1.085520
# 1    19.136947   5.697343   1035.763062     250.505219       1.285628
# 2     8.123428   3.953116    976.207064     404.979103       0.258189
# 3    35.994893   0.509678    966.919462     463.568608       1.040956
# 4    14.793481  52.450884    953.229351      79.514604       1.583390
#
#    PM2.5 Emissions  VOC Emissions  SO2 Emissions Emission Level
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()
for i in ["Vehicle Type","Fuel Type","Road Type","Traffic Conditions","Emission Level"]:
  df[i] = LabelEncoder.fit_transform(df[i])
df.head()
# Out:
#    Vehicle Type  Fuel Type  Age of Vehicle  Road Type  Traffic Conditions  \
# 0             2          1              22          1                   2
# 1             0          1               3          0                   1
# 2             0          2              17          1                   0
# 3             3          1               4          2                   1
# 4             3          2              15          1                   2
#
#    Temperature   Humidity  Air Pressure  CO2 Emissions  NOx Emissions  \
# 0    13.880458  52.883905    955.411642     179.930088       1.085520
# 1    19.136947   5.697343   1035.763062     250.505219       1.285628
# 2     8.123428   3.953116    976.207064     404.979103       0.258189
# 3    35.994893   0.509678    966.919462     463.568608       1.040956
# 4    14.793481  52.450884    953.229351      79.514604       1.583390
#
#    PM2.5 Emissions  VOC Emissions  SO2 Emissions  Emission Level
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Vehicle Type        10000 non-null  int64
#  1   Fuel Type           10000 non-null  int64
#  2   Age of Vehicle      10000 non-null  int64
#  3   Road Type           10000 non-null  int64
#  4   Traffic Conditions  10000 non-null  int64
#  5   Temperature         10000 non-null  float64
#  6   Humidity            10000 non-null  float64
#  7   Air Pressure        10000 non-null  float64
#  8   CO2 Emissions       10000 non-null  float64
#  9   NOx Emissions       10000 non-null  float64
#  10  PM2.5 Emissions     10000 non-null  float64
#  11  VOC Emissions       10000 non-null  float64
#  12  SO2 Emissions       10000 non-null  float64
#  13  Emission Level      10000 non-null  int64
# dtypes: float64(8), int64(6)
# memory usage: 1.1 MB

# %%
x = df.iloc[:,0:13]
x
# Out:
#       Vehicle Type  Fuel Type  Age of Vehicle  Road Type  Traffic Conditions  \
# 0                2          1              22          1                   2
# 1                0          1               3          0                   1
# 2                0          2              17          1                   0
# 3                3          1               4          2                   1
# 4                3          2              15          1                   2
# ...            ...        ...             ...        ...                 ...
# 9995             2          1               1          1                   2
# 9996             0          0               5          0                   0
# 9997             0          3               8          1                   0
# 9998             0          2               2          2                   1
# 9999             1          3              15          2                   0
#
# ...

# %%
y = df['Emission Level']
y
# Out:
# 0       2
# 1       2
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    0
# 9998    2
# 9999    0
# Name: Emission Level, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
ypred = model.predict(xtest)
ypred
# Out:
# array([0, 1, 0, ..., 1, 2, 0])

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(ytest, ypred)
conf_matrix = confusion_matrix(ytest, ypred)
class_report = classification_report(ytest, ypred)

print("Model Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Model Accuracy: 0.9925
# Confusion Matrix:
#  [[880   0   4]
#  [  0 458   3]
#  [  1   7 647]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       884
#            1       0.98      0.99      0.99       461
#            2       0.99      0.99      0.99       655
#
#     accuracy                           0.99      2000
#    macro avg       0.99      0.99      0.99      2000
# weighted avg       0.99      0.99      0.99      2000

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(xtrain, ytrain)
ypred = svm.predict(xtest)
print("Using SVM",accuracy_score(ytest,ypred))
# Out:
# Using SVM 0.961

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(xtrain, ytrain)
ypred = rf.predict(xtest)
print("Using RF",accuracy_score(ytest,ypred))
# Out:
# Using RF 0.9995
